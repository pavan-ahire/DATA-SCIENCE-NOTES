# %%
from scipy.stats import multinomial

# %%
n=20
pvals=[0.6,0.3, 0.1]

samples=multinomial.rvs(n, pvals, size=5)

pmf=multinomial.pmf([6,3,1], n, pvals)

print(samples)
print(pmf)
# Out:
# [[13  5  2]
#  [13  7  0]
#  [12  5  3]
#  [13  7  0]
#  [10  9  1]]
# 0.0
