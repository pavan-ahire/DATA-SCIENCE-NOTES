# %% [markdown]
# # Descriptive statistics

# %%
import statistics as stats

data = [38, 32, 41, 50, 5, 28, 36]

# Mean
mean_value = stats.mean(data)

# Median
median_value = stats.median(data)

# Mode (handle if no mode)
try:
    mode_value = stats.mode(data)
except:
    mode_value = "No mode"

# Variance (population)
variance_value = stats.pvariance(data)

# Standard Deviation (population)
sd_value = stats.pstdev(data)

print("Mean:", mean_value)
print("Median:", median_value)
print("Mode:", mode_value)
print("Variance:", variance_value)
print("Standard Deviation:", sd_value)
# Out:
# Mean: 32.857142857142854
# Median: 36
# Mode: 38
# Variance: 170.9795918367347
# Standard Deviation: 13.075916481713039
