# %% [markdown]
# **1. Create a dictionary with keys as names of students and values as their marks. initialize the dictionary with at least 3 students names and their corresponding marks.**

# %%
std = {"vaibhav":90,"pavan":89,"devendra":93}
print(std)
# Out:
# {'vaibhav': 90, 'pavan': 89, 'devendra': 93}

# %% [markdown]
# **2. Give the dictionary {'a':1,'b':2,'c':3}, how can you access the value of the key 'b'.**

# %%
a = {'a':1,'b':2,'c':3}
a['b']
# Out:
# 2

# %% [markdown]
# **3. Add a new key-value pairs to the fillowing dictionary{'x':10,'y':20} where the key is 'z' and the value is 30.**

# %%
a = {'x':10,'y':20}
a['z'] = 30
a
# Out:
# {'x': 10, 'y': 20, 'z': 30}

# %% [markdown]
# **4 How would you remove the key-value pair 'b':2 from the dictionary {'a':1,'b':2,'c':3}?**

# %%
m = {'a':1,'b':2,'c':3}
m
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
m.pop('b')
# Out:
# 2

# %%
m
# Out:
# {'a': 1, 'c': 3}

# %% [markdown]
# **5 Chek if the dictionary {'a':1,'b':2,'c':3} contains the key 'b'.**

# %%
a = {'a':1,'b':2,'c':3}
print('b' in a)
# Out:
# True

# %%
a.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %% [markdown]
# **6 Merge two dictionaries: dict1 = {'a':1,'b':2} and dict2 = {'c':3,'d':4} into a new dictionary.**

# %%
dict1 = {'a':1,'b':2} 
dict2 = {'c':3,'d':4}
x = {**dict1,**dict2}
x
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# **7 How would you get all the keys from the dictionary {'name':'john','age':25}?.**

# %%
b =  {'name':'john','age':25}
b.keys()
# Out:
# dict_keys(['name', 'age'])

# %% [markdown]
# **8 Create a ditionary with keys as the first letters of the alphabet (e.g, 'a','b','c') and the corresponding value as their ASCII values.**

# %%
asci = {'a':97,'b':98,'c':99,'d':100}
asci
# Out:
# {'a': 97, 'b': 98, 'c': 99, 'd': 100}

# %% [markdown]
# **9 Using the dictionary {'apple':5,'banana':3}, update the value of the key 'apple' to 10.**

# %%
fruits = {'apple':5,'banana':3}
fruits
# Out:
# {'apple': 5, 'banana': 3}

# %%
fruits['apple'] = 10
fruits
# Out:
# {'apple': 10, 'banana': 3}

# %% [markdown]
# **10 Give the dictionary {'name':'Alice','age':30}, hoe can you fetch all the values in the dictionary.**

# %%
a = {'name':'Alice','age':30}
a.values()
# Out:
# dict_values(['Alice', 30])
