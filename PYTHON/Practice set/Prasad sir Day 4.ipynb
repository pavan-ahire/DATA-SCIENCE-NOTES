# %% [markdown]
# **1. create a dictinary that maps the following keys to values: 'apple'->3, 'banana'->5,'orange'->2.**

# %%
fruits = {'apple':3,'banana':5,'orange':2}
fruits
# Out:
# {'apple': 3, 'banana': 5, 'orange': 2}

# %% [markdown]
# **2. Access the value associated with the key 'banana' from the dictionary:
# fruit = {'apple':3,'banana':5,'orange':2}.**

# %%
fruit = {'apple':3,'banana':5,'orange':2}
fruit['banana']
# Out:
# 5

# %% [markdown]
# **3. Add a new key-value pair 'grape':4 to the dictionary:
# fruit = {'apple':3,'banana':5,'orange':2}**

# %%
fruit = {'apple':3,'banana':5,'orange':2}
fruit['grapes'] = 4
fruit
# Out:
# {'apple': 3, 'banana': 5, 'orange': 2, 'grapes': 4}

# %% [markdown]
# **4. Update the value of 'orange' to 10 in the dictionary:
# fruit = {'apple':3,'banana':5,'orange':2}.**

# %%
fruit = {'apple':3,'banana':5,'orange':2}
fruit['orange'] = 10
fruit
# Out:
# {'apple': 3, 'banana': 5, 'orange': 10}

# %% [markdown]
# **5. remove the key 'banana' from the dictionary using the del statement:
# fruit = {'apple':3,'banana':5,'orange':2}.**

# %%
fruit = {'apple':3,'banana':5,'orange':2}
del fruit['banana']
fruit
# Out:
# {'apple': 3, 'orange': 2}

# %% [markdown]
# **6. Check if 'apple' exists as a key in the dictionary:
#  fruit = {'apple':3,'banana':5,'orange':2}.**

# %%
print('apple' in fruit)
# Out:
# True

# %% [markdown]
# **7. Get all the keys from the dictionary:.
# fruit = {'apple':3,'banana':5,'orange':2}.**

# %%
fruit = {'apple':3,'banana':5,'orange':2}
fruit.keys()
# Out:
# dict_keys(['apple', 'banana', 'orange'])

# %% [markdown]
# **8. Get all the vlues from the dictionary.
# fruit = {'apple':3,'banana':5,'orange':2}.**

# %%
fruit = {'apple':3,'banana':5,'orange':2}
fruit.values()
# Out:
# dict_values([3, 5, 2])

# %% [markdown]
# **9. clear all items from the dictionary.
# fruit = {'apple':3,'banana':5,'orange':2}.**

# %%
fruit = {'apple':3,'banana':5,'orange':2}
fruit.clear()
fruit
# Out:
# {}

# %% [markdown]
# **10. copy the dictionary into new variable.
# fruit = {'apple':3,'banana':5,'orange':2}.**

# %%
fruit = {'apple':3,'banana':5,'orange':2}
frt = fruit.copy()
frt
# Out:
# {'apple': 3, 'banana': 5, 'orange': 2}

# %%
id(fruit)
# Out:
# 1565270688064

# %%
id(frt)
# Out:
# 1565270689024

# %%
fruit== frt
# Out:
# True

# %%
id(fruit)==id(frt)
# Out:
# False

# %%
# Out:
# True
