# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
data = [3,4,6,9,10]
data
# Out:
# [3, 4, 6, 9, 10]

# %%
import numpy as np

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
series = pd.Series(data,dtype=np.int16)

# %%
series
# Out:
# 0     3
# 1     4
# 2     6
# 3     9
# 4    10
# dtype: int16

# %%
print(type(series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# creating a series from dictionary

data_dict = {"a":10,"b":20,"c":30,"d":40}
data_dict
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %%
type(data_dict)
# Out:
# dict

# %%
series_dict = pd.Series(data_dict)
series_dict
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
series_dict.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s = pd.Series([2,'a',3.45,True])

# %%
s
# Out:
# 0       2
# 1       a
# 2    3.45
# 3    True
# dtype: object

# %%
s[0]
# Out:
# 2

# %%
arr = np.random.randint(10,50,(9,))
arr
# Out:
# array([41, 10, 47, 44, 43, 46, 34, 29, 42])

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
s2 = pd.Series(arr)

# %%
s2
# Out:
# 0    41
# 1    10
# 2    47
# 3    44
# 4    43
# 5    46
# 6    34
# 7    29
# 8    42
# dtype: int32

# %%
marks = {"Ram":100,"Navin":90,"Praveen":80}
marks
# Out:
# {'Ram': 100, 'Navin': 90, 'Praveen': 80}

# %%
names_marks = pd.Series(marks)
names_marks
# Out:
# Ram        100
# Navin       90
# Praveen     80
# dtype: int64

# %%
arr
# Out:
# array([41, 10, 47, 44, 43, 46, 34, 29, 42])

# %%
list("abcdefghij")
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
try:
    s2 = pd.Series(arr,index = list("abcdefghij"))
    print(s2)
except Exception as e:
    print(e)
# Out:
# Length of values (9) does not match length of index (10)

# %%
try:
    s2 = pd.Series(arr,index = list("abcdefghi"))
    print(s2)
except Exception as e:
    print(e)
# Out:
# a    41
# b    10
# c    47
# d    44
# e    43
# f    46
# g    34
# h    29
# i    42
# dtype: int32

# %%
s2.loc['d']#location
# Out:
# 44

# %%
s2.iloc[3]# index location
# Out:
# 44

# %%
s2['d']
# Out:
# 44

# %%
s2.loc['b':'f']
# Out:
# b    10
# c    47
# d    44
# e    43
# f    46
# dtype: int32

# %%
s2.iloc[0:3]
# Out:
# a    41
# b    10
# c    47
# dtype: int32

# %%
s2.iloc[[1,6]]
# Out:
# b    10
# g    34
# dtype: int32

# %%
[10,20,11,14,15]+[2,-1,5,3,9]
# Out:
# [10, 20, 11, 14, 15, 2, -1, 5, 3, 9]

# %%
list(map(lambda x,y:x+y,[10,20,11,14,15],[2,-1,5,3,9]))
# Out:
# [12, 19, 16, 17, 24]

# %%
sa = pd.Series([10,20,11,14,15])
sb = pd.Series([2,-1,5,3,9])
sa+sb
# Out:
# 0    12
# 1    19
# 2    16
# 3    17
# 4    24
# dtype: int64

# %%
sb+5
# Out:
# 0     7
# 1     4
# 2    10
# 3     8
# 4    14
# dtype: int64

# %%
sa
# Out:
# 0    10
# 1    20
# 2    11
# 3    14
# 4    15
# dtype: int64

# %%
print(sa>14)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
sa[sa>14]
# Out:
# 1    20
# 4    15
# dtype: int64

# %%
def square(x):
    return x*x

squared_series = sa.apply(square)
print(squared_series)
# Out:
# 0    100
# 1    400
# 2    121
# 3    196
# 4    225
# dtype: int64

# %%
sq_series = sa.apply(lambda x:x*x)
sq_series
# Out:
# 0    100
# 1    400
# 2    121
# 3    196
# 4    225
# dtype: int64

# %%
fruits = pd.Series(["Apple","Mango","Banana"])
fruits
# Out:
# 0     Apple
# 1     Mango
# 2    Banana
# dtype: object

# %%
def lower(x):
    return x.lower()

lower_fruits = fruits.apply(lower)

# %%
lower_fruits
# Out:
# 0     apple
# 1     mango
# 2    banana
# dtype: object

# %%
type(lower_fruits)
# Out:
# pandas.core.series.Series

# %%
fruits = pd.Series(["Apple","Mango","Banana"])

# %%
lower_fruits_using_str = fruits.str.lower()

# %%
lower_fruits_using_str
# Out:
# 0     apple
# 1     mango
# 2    banana
# dtype: object

# %%
data_m = [10,20,None,40,None]

series_nan = pd.Series(data_m)
series_nan
# Out:
# 0    10.0
# 1    20.0
# 2     NaN
# 3    40.0
# 4     NaN
# dtype: float64

# %%
series_nan.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
series_nan.isna().any()
# Out:
# True

# %%
series_nan.isna().sum()
# Out:
# 2

# %%
series_nan.notna()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
data_m = [10,20,30,40,None,np.nan,30,24,np.nan]
series_1 = pd.Series(data_m)
series_1
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4     NaN
# 5     NaN
# 6    30.0
# 7    24.0
# 8     NaN
# dtype: float64

# %%
series_1.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# dtype: bool

# %%
series_1.isna().sum()
# Out:
# 3

# %%
series_1.isna().any()
# Out:
# True

# %%
series_1[series_1.isna()]
# Out:
# 4   NaN
# 5   NaN
# 8   NaN
# dtype: float64

# %%
series_1[series_1.notna()]
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 6    30.0
# 7    24.0
# dtype: float64

# %%
series_nan
# Out:
# 0    10.0
# 1    20.0
# 2     NaN
# 3    40.0
# 4     NaN
# dtype: float64

# %%
series_nan.mean()
# Out:
# 23.333333333333332

# %%
series_nan.mean(skipna = False)
# Out:
# nan

# %%
series_no_null = pd.Series([10,20,30,40,np.nan])

# %%
series_no_null.mean()
# Out:
# 25.0

# %%
s2
# Out:
# a    41
# b    10
# c    47
# d    44
# e    43
# f    46
# g    34
# h    29
# i    42
# dtype: int32

# %%
s2.mean()
# Out:
# 37.333333333333336

# %%
s2.sort_values()
# Out:
# b    10
# h    29
# g    34
# a    41
# i    42
# e    43
# d    44
# f    46
# c    47
# dtype: int32

# %%
s2.sort_values(ignore_index=True)
# Out:
# 0    10
# 1    29
# 2    34
# 3    41
# 4    42
# 5    43
# 6    44
# 7    46
# 8    47
# dtype: int32

# %%
s2.sort_values(ascending=False)
# Out:
# c    47
# f    46
# d    44
# e    43
# i    42
# a    41
# g    34
# h    29
# b    10
# dtype: int32

# %%
series_s = pd.Series([12,46,44,20,33,42,25,15,36,42])
series_s
# Out:
# 0    12
# 1    46
# 2    44
# 3    20
# 4    33
# 5    42
# 6    25
# 7    15
# 8    36
# 9    42
# dtype: int64

# %%
series_s = pd.DataFrame([12,46,44,20,33,42,25,15,36,42])

# %%
series_s
# Out:
#     0
# 0  12
# 1  46
# 2  44
# 3  20
# 4  33
# 5  42
# 6  25
# 7  15
# 8  36
# 9  42

# %%
series_s.sort_values(by=0,ignore_index=True,axis=0)
# Out:
#     0
# 0  12
# 1  15
# 2  20
# 3  25
# 4  33
# 5  36
# 6  42
# 7  42
# 8  44
# 9  46

# %%
import pandas as pd

# %%
data = {
    "A":[1,2,3,4],
    "B":[3,1,4,1],
    "C":[12,10,-1,0]
}
df = pd.DataFrame(data)
df
# Out:
#    A  B   C
# 0  1  3  12
# 1  2  1  10
# 2  3  4  -1
# 3  4  1   0

# %%
data = {
    "A":[1,2,3,4],
    "B":[3,1,4,1],
    "C":[12,10,-1,0]
}
df = pd.DataFrame(data,index=["r"+str(i) for i in range(len(data["A"]))])
df
# Out:
#     A  B   C
# r0  1  3  12
# r1  2  1  10
# r2  3  4  -1
# r3  4  1   0

# %%
data = {
    "A":[1,2,3,4],
    "B":[3,1,4,1],
    "C":[12,10,-1,0]
}
df = pd.DataFrame(data,index=["r"+str(i) for i in range(len(data["A"]))])
df.columns = ["C"+str(i) for i in range(len(data.keys()))]
df
# Out:
#     C0  C1  C2
# r0   1   3  12
# r1   2   1  10
# r2   3   4  -1
# r3   4   1   0

# %%
df["sum"] =df.sum(axis=1)
df
# Out:
#     C0  C1  C2  sum
# r0   1   3  12   16
# r1   2   1  10   13
# r2   3   4  -1    6
# r3   4   1   0    5

# %%
data = {
    "English":[100,100,100],
    "Math":[99,89,91],
    "Physics":[100,92,96]
}
marks = pd.DataFrame(data,index = ["Ram","Sham","Tom"])
marks
# Out:
#       English  Math  Physics
# Ram       100    99      100
# Sham      100    89       92
# Tom       100    91       96

# %%
marks["total"] = marks.sum(axis=1)
marks
# Out:
#       English  Math  Physics  total
# Ram       100    99      100    299
# Sham      100    89       92    281
# Tom       100    91       96    287

# %%
marks["total"]
# Out:
# Ram     299
# Sham    281
# Tom     287
# Name: total, dtype: int64

# %%
marks["English"]
# Out:
# Ram     100
# Sham    100
# Tom     100
# Name: English, dtype: int64

# %%
marks.loc['Ram']
# Out:
# English    100
# Math        99
# Physics    100
# total      299
# Name: Ram, dtype: int64

# %%
marks.iloc[0:1,:]
# Out:
#      English  Math  Physics  total
# Ram      100    99      100    299

# %%
marks[['Math']]
# Out:
#       Math
# Ram     99
# Sham    89
# Tom     91

# %%
marks['avg'] = marks['total']/3
marks
# Out:
#       English  Math  Physics  total        avg
# Ram       100    99      100    299  99.666667
# Sham      100    89       92    281  93.666667
# Tom       100    91       96    287  95.666667

# %%
marks.mean(axis=0)
# Out:
# English    100.000000
# Math        93.000000
# Physics     96.000000
# total      289.000000
# avg         96.333333
# dtype: float64

# %%
marks.columns
# Out:
# Index(['English', 'Math', 'Physics', 'total', 'avg'], dtype='object')

# %%
list('abcde')
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
marks.columns = list('abcde')
marks
# Out:
#         a   b    c    d          e
# Ram   100  99  100  299  99.666667
# Sham  100  89   92  281  93.666667
# Tom   100  91   96  287  95.666667

# %%
data = {
    "A":[1,2,3,4],
    "B":[3,1,4,1],
    "C":[12,10,-1,0]
}
df = pd.DataFrame(data,index=["r"+str(i) for i in range(len(data["A"]))])
df.columns = ["C"+str(i) for i in range(len(data.keys()))]
df
# Out:
#     C0  C1  C2
# r0   1   3  12
# r1   2   1  10
# r2   3   4  -1
# r3   4   1   0

# %%
df["C1"] = df["C1"].apply(lambda x:x**2)
df
# Out:
#     C0  C1  C2
# r0   1   9  12
# r1   2   1  10
# r2   3  16  -1
# r3   4   1   0

# %%
s1 = pd.Series([34,89,76,23,24])
s1
# Out:
# 0    34
# 1    89
# 2    76
# 3    23
# 4    24
# dtype: int64

# %%
data = pd.DataFrame(s1,columns = ["column1"])
data
# Out:
#    column1
# 0       34
# 1       89
# 2       76
# 3       23
# 4       24

# %%
data.iloc[2]
# Out:
# column1    76
# Name: 2, dtype: int64

# %%
data.column1[2]
# Out:
# 76

# %%
data['column1'][2]
# Out:
# 76

# %%
data = {
    "Row1":["john",24,"B.Com"],
    "Row2":["Nick",35,"B.E"],
    "Row3":["Tom",45,"B.Arch"]
}
df = pd.DataFrame.from_dict(data)
df
# Out:
#     Row1  Row2    Row3
# 0   john  Nick     Tom
# 1     24    35      45
# 2  B.Com   B.E  B.Arch

# %%
data = {
    "Row1":["john",24,"B.Com"],
    "Row2":["Nick",35,"B.E"],
    "Row3":["Tom",45,"B.Arch"]
}
df = pd.DataFrame.from_dict(data,orient = "index",columns = ['Name','Age','Qualifiction'])
df
# Out:
#       Name  Age Qualifiction
# Row1  john   24        B.Com
# Row2  Nick   35          B.E
# Row3   Tom   45       B.Arch

# %%
data = {
    "Row1":["john",24,"B.Com"],
    "Row2":["Nick",35,"B.E"],
    "Row3":["Tom",45,"B.Arch"]
}
df = pd.DataFrame.from_dict(data,orient = "index")
df
# Out:
#          0   1       2
# Row1  john  24   B.Com
# Row2  Nick  35     B.E
# Row3   Tom  45  B.Arch

# %%
data = {
    "Name":["A","B","C","D"],
    "Desiganation":["PM","Dev","Tm","Tester"],
    "Location":["Delhi","Hydrabad","Chennai","Vizag"],
    "Salary":[20,30,43,9]
}
df = pd.DataFrame(data)
df
# Out:
#   Name Desiganation  Location  Salary
# 0    A           PM     Delhi      20
# 1    B          Dev  Hydrabad      30
# 2    C           Tm   Chennai      43
# 3    D       Tester     Vizag       9

# %%
df.index=["person"+f"{i}" for i in range(1,1+len(data["Name"]))]
df
# Out:
#         Name Desiganation  Location  Salary
# person1    A           PM     Delhi      20
# person2    B          Dev  Hydrabad      30
# person3    C           Tm   Chennai      43
# person4    D       Tester     Vizag       9
