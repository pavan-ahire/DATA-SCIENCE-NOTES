# %% [markdown]
# **1 Create a list: create a list of your 5 favourite fruits.**

# %%
fruits = ["apple","mango","banana","Orange","watermelon"]
fruits
# Out:
# ['apple', 'mango', 'banana', 'Orange', 'watermelon']

# %% [markdown]
# **2.Access elements: How do you access the second item in the list my_list = [10,20,30,40,50]?**

# %%
my_list = [10,20,30,40,50]
my_list[1]
# Out:
# 20

# %% [markdown]
# **3 Add item: Add the number 60 from the list [1,2,3,4,5].**

# %%
lis = [1,2,3,4,5]
lis.append(60)
print(lis)
# Out:
# [1, 2, 3, 4, 5, 60]

# %% [markdown]
# **4 Remove items: Remove the number 3 from the list [1,2,3,4,5].**

# %%
list1 = [1,2,3,4,5]
list1.remove(3)
print(list1)
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# **5 List Length: Find the length of the list numbers = [5,10,15,20,25].**

# %%
numbers = [5,10,15,20,25]
len(numbers)
# Out:
# 5

# %% [markdown]
# **6 Check Membership: Write a program to check if the number 10 is in the list[1,2,3,4,5,10].**

# %%
num = [1,2,3,4,5,10]
print( 10 in num)
# Out:
# True

# %% [markdown]
# **7 Loop through list: Write a loop to print each item in the list['apple,'banana',cherry'].**

# %%
fruits = ['apple','banana','cherry']
for i in fruits:
    print(i)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# **8 List Slicing: What does my_list[1:4] return if my_list=[0,1,2,3,4,5]?**

# %%
my_list = [0,1,2,3,4,5]
my_list[1:4]
# Out:
# [1, 2, 3]

# %% [markdown]
# **9 Reverse a List: How do you reverse the list [1,2,3,4,5]?**

# %%
list1 = [1,2,3,4,5]
list1[::-1]
#list1.reverse()
#print(list1)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# **10 Find the maximum: Write a program to find the maximum number in the list [3,7,1,9,5].**

# %%
num = [3,7,1,9,5]
max(num)
# Out:
# 9
